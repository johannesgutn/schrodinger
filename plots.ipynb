# %%
import matplotlib.pyplot as plt
import numpy as np

all = np.load('data_files/sch_p=0.1_theta=0.1_gridpoints=60_gridsize=3_L=0.5_E=5_z=0.4.npy')

t = all[0]
full1 = all[1]
full2 = all[2]
Nc1 = all[3]
Nc2 = all[4]
Nc1_true = all[5]

# %%
plt.plot(t,np.real(full1), label='K1 Numeric-full-re',color='C0')
plt.plot(t,np.imag(full1), label='K1 Numeric-full-im',linestyle='--',color='C0')

plt.plot(t,np.real(full2), label='K2 Numeric-full-re',color='C1')
plt.plot(t,np.imag(full2), label='K2 Numeric-full-im',linestyle='--',color='C1')


plt.legend()
plt.show()

# %%
plt.plot(t,np.real(Nc1),label='Nc K1 real',linestyle='--',color='C0')
plt.plot(t,np.real(Nc1_true),label='Nc K1 real true value',linestyle=':',color='C0')
plt.plot(t,np.real(full1),label='Full K1 real',color='C0')

plt.plot(t,np.imag(Nc1),label='Nc K1 imag',linestyle='--',color='C1')
plt.plot(t,np.imag(Nc1_true),label='Nc K1 imag true value',linestyle=':',color='C1')
plt.plot(t,np.imag(full1),label='Full K1 imag',color='C1')

plt.legend()
plt.show()

# %%
plt.plot(t,np.real(Nc2),label='Nc K2 real',linestyle='--',color='C0')
plt.plot(t,np.real(full2),label='Full K2 real',color='C0')

plt.plot(t,np.imag(Nc2),label='Nc K2 imag',linestyle='--',color='C1')
plt.plot(t,np.imag(full2),label='Full K2 imag',color='C1')

plt.legend()
plt.show()
# Out:
# /Users/johannes/opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1390: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('data_files/fails.csv')
df.head(10)
# Out:
#         ω      z    E       p  grid_points  grid_size  L  t_failed  worked?
# 0    1.66  0.210   10   0.331           50          3  2     2.000     True
# 1    0.35  0.037   10   0.071           60          3  2     2.000     True
# 2   25.00  0.500  100   5.000           50          3  2     2.000     True
# 3   16.57  0.210  100   3.314           50          3  2     2.000     True
# 4   10.95  0.324   50   2.189           50          3  2     2.000     True
# 5    0.80  0.088   10   0.160           60          3  2     2.000     True
# 6    2.50  0.500   10   0.500           50          3  2     2.000     True
# 7   12.50  0.500   50   2.500           50          3  2     2.000     True
# 8    2.19  0.324   10   0.438           50          3  2     2.000     True
# 9   21.89  0.324  100   4.379           50          3  2     2.000     True
# 10   8.28  0.210   50   1.657           50          3  2     2.000     True
# 11   0.54  0.057   10   0.107           60          3  2     2.000     True
# 12  25.00  0.500  100   0.250           40          3  2     1.929    False
# 13  25.00  0.500  100  12.500           40          3  2     1.929    False
# 14  12.50  0.500   50   6.250           40          3  2     1.726    False
# 15  12.50  0.500   50   0.125           40          3  2     1.714    False
# 16  11.73  0.136  100   2.346           50          3  2     1.474    False
# 17  21.89  0.324  100  10.947           40          3  2     1.417    False
# 18  21.89  0.324  100   0.219           40          3  2     1.405    False
# 19   0.23  0.024   10   0.047           60          3  2     1.326    False
# 20   0.23  0.024   10   0.047           60          3  2     1.326    False
# 21   5.87  0.136   50   1.173           50          3  2     1.301    False
# 22  10.95  0.324   50   0.109           40          3  2     1.274    False
# 23  10.95  0.324   50   5.473           40          3  2     1.250    False
# 24   2.50  0.500   10   0.025           40          3  2     1.202    False
# 25   2.50  0.500   10   1.250           40          3  2     1.202    False
# 26   8.02  0.088  100   1.603           50          3  2     1.053    False
# 27  16.57  0.210  100   8.284           40          3  2     0.988    False
# 28  16.57  0.210  100   0.166           40          3  2     0.988    False
# 29   1.17  0.136   10   0.235           50          3  2     0.917    False

# %%
df40 = df[df.grid_points == 40]
df40.sort_values(['ω','z','E']).head(40)
# Out:
#         ω      z    E      p  grid_points  grid_size  L  t_failed  worked?
# 101  0.10  0.010   10  0.001           40          3  2  0.155000    False
# 102  0.10  0.010   10  0.049           40          3  2  0.155000    False
# 111  0.10  0.010   10  0.020           40          3  2  0.012000    False
# 97   0.15  0.015   10  0.002           40          3  2  0.214000    False
# 98   0.15  0.015   10  0.076           40          3  2  0.214000    False
# 109  0.15  0.015   10  0.030           40          3  2  0.012000    False
# 92   0.23  0.024   10  0.116           40          3  2  0.274000    False
# 93   0.23  0.024   10  0.002           40          3  2  0.262000    False
# 110  0.23  0.024   10  0.047           40          3  2  0.012000    False
# 88   0.35  0.037   10  0.177           40          3  2  0.310000    False
# 90   0.35  0.037   10  0.004           40          3  2  0.298000    False
# 106  0.35  0.037   10  0.071           40          3  2  0.012000    False
# 86   0.49  0.010   50  0.005           40          3  2  0.321000    False
# 87   0.49  0.010   50  0.247           40          3  2  0.321000    False
# 83   0.54  0.057   10  0.005           40          3  2  0.345000    False
# 84   0.54  0.057   10  0.268           40          3  2  0.345000    False
# 107  0.54  0.057   10  0.107           40          3  2  0.012000    False
# 79   0.76  0.015   50  0.380           40          3  2  0.357000    False
# 80   0.76  0.015   50  0.008           40          3  2  0.357000    False
# 75   0.80  0.088   10  0.008           40          3  2  0.405000    False
# 76   0.80  0.088   10  0.401           40          3  2  0.405000    False
# 108  0.80  0.088   10  0.160           40          3  2  0.012000    False
# 112  0.99  0.010  100  0.495           40          3  2  0.011905    False
# 114  0.99  0.010  100  0.010           40          3  2  0.011905    False
# 74   1.16  0.024   50  0.582           40          3  2  0.405000    False
# 77   1.16  0.024   50  0.012           40          3  2  0.405000    False
# 61   1.17  0.136   10  0.587           40          3  2  0.488000    False
# 62   1.17  0.136   10  0.012           40          3  2  0.488000    False
# 71   1.52  0.015  100  0.760           40          3  2  0.429000    False
# 113  1.52  0.015  100  0.015           40          3  2  0.011905    False
# 45   1.66  0.210   10  0.828           40          3  2  0.619000    False
# 46   1.66  0.210   10  0.017           40          3  2  0.619000    False
# 68   1.77  0.037   50  0.887           40          3  2  0.452000    False
# 69   1.77  0.037   50  0.018           40          3  2  0.452000    False
# 31   2.19  0.324   10  0.022           40          3  2  0.893000    False
# 32   2.19  0.324   10  1.095           40          3  2  0.893000    False
# 64   2.33  0.024  100  1.164           40          3  2  0.476000    False
# 65   2.33  0.024  100  0.023           40          3  2  0.476000    False
# 24   2.50  0.500   10  0.025           40          3  2  1.202000    False
# 25   2.50  0.500   10  1.250           40          3  2  1.202000    False

# %%
df50 = df[df.grid_points == 50]
df50.sort_values(['ω','z','E']).head(40)
# Out:
#          ω      z    E      p  grid_points  grid_size  L  t_failed  worked?
# 103   0.10  0.010   10  0.020           50          3  2     0.120    False
# 94    0.15  0.015   10  0.030           50          3  2     0.241    False
# 85    0.23  0.024   10  0.047           50          3  2     0.338    False
# 72    0.35  0.037   10  0.071           50          3  2     0.414    False
# 73    0.49  0.010   50  0.099           50          3  2     0.406    False
# 58    0.54  0.057   10  0.107           50          3  2     0.519    False
# 67    0.76  0.015   50  0.152           50          3  2     0.459    False
# 44    0.80  0.088   10  0.160           50          3  2     0.654    False
# 66    0.99  0.010  100  0.198           50          3  2     0.474    False
# 55    1.16  0.024   50  0.233           50          3  2     0.526    False
# 29    1.17  0.136   10  0.235           50          3  2     0.917    False
# 54    1.52  0.015  100  0.304           50          3  2     0.549    False
# 0     1.66  0.210   10  0.331           50          3  2     2.000     True
# 48    1.77  0.037   50  0.355           50          3  2     0.609    False
# 8     2.19  0.324   10  0.438           50          3  2     2.000     True
# 47    2.33  0.024  100  0.466           50          3  2     0.617    False
# 6     2.50  0.500   10  0.500           50          3  2     2.000     True
# 38    2.68  0.057   50  0.537           50          3  2     0.729    False
# 39    3.55  0.037  100  0.710           50          3  2     0.714    False
# 30    4.01  0.088   50  0.802           50          3  2     0.910    False
# 35    5.37  0.057  100  1.073           50          3  2     0.842    False
# 21    5.87  0.136   50  1.173           50          3  2     1.301    False
# 26    8.02  0.088  100  1.603           50          3  2     1.053    False
# 10    8.28  0.210   50  1.657           50          3  2     2.000     True
# 4    10.95  0.324   50  2.189           50          3  2     2.000     True
# 16   11.73  0.136  100  2.346           50          3  2     1.474    False
# 7    12.50  0.500   50  2.500           50          3  2     2.000     True
# 3    16.57  0.210  100  3.314           50          3  2     2.000     True
# 9    21.89  0.324  100  4.379           50          3  2     2.000     True
# 2    25.00  0.500  100  5.000           50          3  2     2.000     True

# %%
df60 = df[df.grid_points == 60]
df60.sort_values(['ω','z','E']).head(60)
# Out:
#         ω      z   E      p  grid_points  grid_size  L  t_failed  worked?
# 104  0.10  0.010  10  0.020           60          3  2     0.078    False
# 105  0.10  0.010  10  0.020           60          3  2     0.078    False
# 81   0.15  0.015  10  0.030           60          3  2     0.347    False
# 82   0.15  0.015  10  0.030           60          3  2     0.347    False
# 19   0.23  0.024  10  0.047           60          3  2     1.326    False
# 20   0.23  0.024  10  0.047           60          3  2     1.326    False
# 1    0.35  0.037  10  0.071           60          3  2     2.000     True
# 11   0.54  0.057  10  0.107           60          3  2     2.000     True
# 5    0.80  0.088  10  0.160           60          3  2     2.000     True

# %%
ω40 = np.array(df40['ω'])
t_failed40 = np.array(df40['t_failed'])

ω50 = np.array(df50['ω'])
t_failed50 = np.array(df50['t_failed'])

ω60 = np.array(df60['ω'])
t_failed60 = np.array(df60['t_failed'])


plt.semilogx(ω40,t_failed40)
plt.semilogx(ω50,t_failed50)
plt.semilogx(ω60,t_failed60)
plt.show()
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
z40 = np.array(df40['z'])
t_failed40 = np.array(df40['t_failed'])

z50 = np.array(df50['z'])
t_failed50 = np.array(df50['t_failed'])

z60 = np.array(df60['z'])
t_failed60 = np.array(df60['t_failed'])


plt.semilogx(z40,t_failed40)
plt.semilogx(z50,t_failed50)
plt.semilogx(z60,t_failed60)
plt.show()

# %%
E40 = np.array(df40['E'])
t_failed40 = np.array(df40['t_failed'])

E50 = np.array(df50['E'])
t_failed50 = np.array(df50['t_failed'])

E60 = np.array(df60['E'])
t_failed60 = np.array(df60['t_failed'])


plt.scatter(E40,t_failed40)
plt.scatter(E50,t_failed50)
plt.scatter(E60,t_failed60)
plt.show()

# %%
df = pd.read_csv('data_files/sch_summary.csv')
df=df[df.finite_Nc2!='failed']
df=df[df.L==2]
df40.sort_values(['ω','z','E']).head(40)
df.head()
# Out:
#         p      z    L   E     ω  grid_points  grid_size      finite_Nc1  \
# 21  0.071  0.037  2.0  10  0.35           60          3  (0.106-0.537j)
# 26  0.071  0.037  2.0  10  0.35           60          3  (0.106-0.537j)
# 33  0.107  0.057  2.0  10  0.54           60          3  (0.186-0.757j)
# 44  0.160  0.088  2.0  10  0.80           60          3   (0.334-1.03j)
# 93  0.331  0.210  2.0  10  1.66           50          3              0j
#
#          large_Nc1        true_Nc1       finite_Nc2             large_Nc2  \
# 21   (0.007-0.01j)  (0.006-0.008j)   (1.311-5.336j)        (1.307-5.333j)
# 26   (0.007-0.01j)  (0.006-0.008j)   (1.311-5.336j)        (1.307-5.333j)
# 33  (0.026-0.035j)  (0.021-0.029j)    (2.253-7.65j)         (2.243-7.64j)
# 44  (0.084-0.117j)  (0.067-0.096j)  (3.818-10.458j)         (3.79-10.43j)
# 93  (0.711-1.011j)   (0.58-0.849j)               0j  (-922.693+1046.092j)
#
#           diag_Nc2   true_Nc2_diag largeNc/finiteNc1 largeNc/finiteNc2  \
# 21  (1.307-5.333j)  (0.006-0.008j)              0.07               1.0
# 26             NaN             NaN              0.02               1.0
# 33             NaN             NaN              0.05               1.0
# 44             NaN             NaN              0.11               1.0
# 93             NaN             NaN              -inf               inf
#
#    diagNc/finiteNc2 error1 error2                    time
# 21             0.99  0.182  0.998  0 days 02:06:49.416354
# 26              NaN  0.182    NaN  0 days 01:23:06.435753
# 33              NaN  0.184    NaN  0 days 01:24:04.967634
# 44              NaN  0.185    NaN  0 days 01:27:20.330640
# 93              NaN  0.169    NaN  0 days 00:12:59.883865

# %%
df40 = df[df.grid_points == 40]
df50 = df[df.grid_points == 50]
df60 = df[df.grid_points == 60]

# %%
dferror = df[['ω','z','E','grid_points','largeNc/finiteNc1','error1']]
dferror.sort_values('ω').head(40)
# Out:
#          ω      z    E  grid_points largeNc/finiteNc1 error1
# 21    0.35  0.037   10           60              0.07  0.182
# 26    0.35  0.037   10           60              0.02  0.182
# 33    0.54  0.057   10           60              0.05  0.184
# 44    0.80  0.088   10           60              0.11  0.185
# 93    1.66  0.210   10           50              -inf  0.169
# 107   2.19  0.324   10           50              0.74  0.158
# 115   2.50  0.500   10           50              0.83  0.154
# 137   8.28  0.210   50           50              -0.0  0.145
# 140  10.95  0.324   50           50               1.0  0.135
# 146  12.50  0.500   50           50               1.0  0.126
# 149  16.57  0.210  100           50               1.0  0.102
# 152  21.89  0.324  100           50               1.0    0.1
# 155  25.00  0.500  100           50               1.0  0.164

# %%
ω40 = np.array(df40['ω'])
error140 = np.array(df40['error1']).astype(float)

ω50 = np.array(df50['ω'])
error150 = np.array(df50['error1']).astype(float)

ω60 = np.array(df60['ω'])
error160 = np.array(df60['error1']).astype(float)


plt.semilogx(ω50,error150,label = '50')
plt.semilogx(ω60,error160,label = '60')

plt.legend()
plt.show()

# %%
print(ω50)
print(error150.astype(float))
type(error150.astype(float)[0])
# Out:
# [ 1.66  2.19  2.5   8.28 10.95 12.5  16.57 21.89 25.  ]
# [0.169 0.158 0.154 0.145 0.135 0.126 0.102 0.1   0.164]
# numpy.float64
